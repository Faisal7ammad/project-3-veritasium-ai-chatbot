# %% [markdown]
# # Veritasium - Batch Vectorization

# %% [markdown]
# ## Downloading & Importing Libraries

# %%
# !pip install transformers langchain langchain_community langchain_openai pinecone-client python-dotenv
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Collecting langchain
#   Downloading langchain-0.2.7-py3-none-any.whl (983 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.6/983.6 kB 10.0 MB/s eta 0:00:00
# Collecting langchain_community
#   Downloading langchain_community-0.2.7-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 23.4 MB/s eta 0:00:00
# Collecting langchain_openai
#   Downloading langchain_openai-0.1.16-py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 4.6 MB/s eta 0:00:00
# Collecting pinecone-client
#   Downloading pinecone_client-4.1.2-py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.4/216.4 kB 18.4 MB/s eta 0:00:00
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.12 (from langchain)
#   Downloading langchain_core-0.2.18-py3-none-any.whl (366 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.3/366.3 kB 31.5 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.85-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.5.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting openai<2.0.0,>=1.32.0 (from langchain_openai)
#   Downloading openai-1.35.13-py3-none-any.whl (328 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.5/328.5 kB 28.9 MB/s eta 0:00:00
# Collecting tiktoken<1,>=0.7 (from langchain_openai)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2019.11.17 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2024.7.4)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone-client)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client) (2.0.7)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.9 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.12->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.32.0->langchain_openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.32.0->langchain_openai) (1.3.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.32.0->langchain_openai) (1.2.1)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain_openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.7 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.32.0->langchain_openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.7 MB/s eta 0:00:00
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.12->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, pinecone-plugin-interface, orjson, mypy-extensions, marshmallow, jsonpointer, h11, typing-inspect, tiktoken, pinecone-client, jsonpatch, httpcore, langsmith, httpx, dataclasses-json, openai, langchain-core, langchain-text-splitters, langchain_openai, langchain, langchain_community
# Successfully installed dataclasses-json-0.6.7 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.7 langchain-core-0.2.18 langchain-text-splitters-0.2.2 langchain_community-0.2.7 langchain_openai-0.1.16 langsmith-0.1.85 marshmallow-3.21.3 mypy-extensions-1.0.0 openai-1.35.13 orjson-3.10.6 pinecone-client-4.1.2 pinecone-plugin-interface-0.0.7 python-dotenv-1.0.1 tiktoken-0.7.0 typing-inspect-0.9.0

# %%
import os
from google.colab import files
from google.colab import userdata
from google.colab import runtime
# from dotenv import load_dotenv

import json
import re
from transformers import pipeline
import torch
from tqdm import tqdm
from typing import List, Dict, Any
import time

from pinecone import Pinecone
from pinecone import ServerlessSpec
from langchain_openai import OpenAI, ChatOpenAI
from langchain.text_splitter import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain.docstore.document import Document
from transformers import BartTokenizer, BartForConditionalGeneration
from langchain.prompts import PromptTemplate

# %%
OPENAI_API_KEY = userdata.get('Ironhack-GPT')
PC_API_KEY = userdata.get('PineCone')
HF_TOKEN = userdata.get('HF')


os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY
os.environ['HF_TOKEN'] = HF_TOKEN

# %%
## Loading Data

# Load the JSON file
with open('/content/2-transcribed_videos_metadata.json', 'r') as f:
    transcribed_videos = json.load(f)

transcribed_videos_original = transcribed_videos.copy() ## keeping for reference

# %% [markdown]
# ## Re-categorization

# %%
# Flatten the video list from all categories
videos = [video for category in transcribed_videos.values() for video in category]

# Inspect the first video
first_video = videos[0]
print(json.dumps(first_video, indent=4))
# Out:
# {
#     "videoId": "scliyWrN7mk",
#     "title": "how bikes *actually* work",
#     "description": "why are bicycles stable? the most common answer is gyroscopic effects, but this is not right.",
#     "published_at": "2024-04-17T16:20:50Z",
#     "url": "https://www.youtube.com/watch?v=scliyWrN7mk",
#     "transcription": "How do bikes without riders stay upright? As long as a bike is moving with sufficient speed, it can keep coasting indefinitely. But it turned out the ground where we went to test this effect was really bumpy. But the bike still manages to absorb all these perturbations.\n and remain stable. So how does it do this? I think most people believe it's the wheels spinning that creates some sort of gyroscopic effect that resists falling over. Just like in this demonstration of gyroscopic precession, the wheels\n stays upright even though gravity is pulling it down. But this is not why bikes are stable. Just watch what happens when we lock the handlebars completely, so you can only go straight ahead.\n The real reason bicycles are stable without riders is because they're cleverly designed to steer themselves. If they start falling to one side, the handlebars turn in that direction to steer the wheels back underneath them."
# }

# %%
# Function to check if a transcription is valid
def is_valid_transcription(transcription):
    return isinstance(transcription, str) and len(transcription) > 50  # valid transcription has more than 50 characters

def remove_repeated_phrases(text):
    # Replace multiple spaces with a single space
    text = re.sub(r'\s+', ' ', text).strip()

    # Remove repeated phrases
    pattern = r'\b(\w+\s+){1,5}(\1)+\b'
    while re.search(pattern, text):
        text = re.sub(pattern, r'\1', text)

    return text

# Function to clean a single transcription
def clean_transcription(transcription):
    # Remove tokens between \n if the number of tokens is less than 3
    def clean_segment(segment):
        tokens = segment.split()
        return segment if len(tokens) >= 3 else ''

    # Split by \n, clean segments, and join back together
    segments = transcription.split('\n')
    cleaned_segments = [clean_segment(segment) for segment in segments]
    cleaned_transcription = ' '.join(cleaned_segments).strip()

    # Remove all remaining \n and repetitive words/phrases
    cleaned_transcription = cleaned_transcription.replace('\n', ' ')
    cleaned_transcription = re.sub(r'\s+', ' ', cleaned_transcription).strip()
    cleaned_transcription = remove_repeated_phrases(cleaned_transcription)

    return cleaned_transcription

# Function to process transcribed_videos and return cleaned version
def clean_transcribed_videos(transcribed_videos):
    for category in transcribed_videos.keys():
        for video in transcribed_videos[category]:
            if 'transcription' in video:
                video['transcription'] = clean_transcription(video['transcription'])
    return transcribed_videos

# Load the transcribed videos metadata from a JSON file
with open('3-transcribed_videos_metadata.json', 'r') as f:
    transcribed_videos_metadata = json.load(f)

# Function to find a video by videoId
def find_video_by_id(transcribed_videos, video_id):
    for category, videos in transcribed_videos.items():
        for video in videos:
            if video['videoId'] == video_id:
                return video
    return None

# ###  TESTING
# # Lookup the video by its ID
# video_id = "oVfHeWTKjag"  # Replace with the desired video ID
# sample_video = find_video_by_id(transcribed_videos_metadata, video_id)

# if sample_video:
#     # Clean the transcription of the sample video
#     sample_video_cleaned = clean_transcription(sample_video['transcription'])

#     # Print the cleaned transcription
#     print(f"Original Transcription:\n{sample_video['transcription']}\n")
#     print(f"Cleaned Transcription:\n{sample_video_cleaned}")
# else:
#     print(f"Video with ID {video_id} not found.")
# Clean the entire dataset

transcribed_videos = clean_transcribed_videos(transcribed_videos)

# %%
# Predefined categories
predefined_categories = [
    "Physics",
    "Mathematics",
    "Engineering",
    "Biology",
    "Chemistry",
    "Space",
    "Technology",
    "Geoscience",
    "General Science",
    "Miscellaneous Educational Content"
]

# Few-shot examples based on transcription
few_shot_examples = [
    {
        "title": "The Wonders of Quantum Physics",
        "transcription": "Quantum physics is a fundamental theory in physics that describes nature at the smallest scales of energy levels of atoms and subatomic particles.",
        "category": "Physics"
    },
    {
        "title": "DIY Experiment",
        "transcription": "This experiment demonstrates chemical reactions that can be easily done at home using common household items. Watch how baking soda reacts with vinegar.",
        "category": "Chemistry"
    },
    {
        "title": "The Future of AI",
        "transcription": "Artificial Intelligence is rapidly advancing. This video discusses the latest developments in AI technology and its potential future applications.",
        "category": "Technology"
    }
]

# Constructing the prompt with few-shot examples
few_shot_text = "\n".join(
    f"Title: {example['title']}\nTranscription: {example['transcription']}\nCategory: {example['category']}"
    for example in few_shot_examples
)

dynamic_prompt_template = f"""
You are an AI that categorizes YouTube videos based on their transcriptions.
You analyze the transcriptions thoroughly and conclude what theme is the video about.
You are very accurate in making this categorization and avoid categorizing in 'Miscellaneous Educational Content' unless absolutely necessary.
Choose the most appropriate category from the following list:
{', '.join(predefined_categories)}

Here are some examples:
{few_shot_text}

Now, categorize the following video:

Title: {{title}}
Transcription: {{transcription}}

Respond with only the most appropriate category for this video, without any additional text.
"""

# Create a LangChain prompt
dynamic_prompt = PromptTemplate(template=dynamic_prompt_template, input_variables=["title", "transcription"])

# Initialize the OpenAI Chat model with a specific name
dynamic_llm = ChatOpenAI(model="gpt-3.5-turbo", openai_api_key=OPENAI_API_KEY)

# Clean the transcriptions
transcribed_videos_metadata = clean_transcribed_videos(transcribed_videos_metadata)

# Filter out videos without valid transcriptions
filtered_videos = {}
for category in transcribed_videos_metadata.keys():
    valid_videos = [video for video in transcribed_videos_metadata[category] if 'transcription' in video and is_valid_transcription(video['transcription'])]
    if len(valid_videos) > 0:
        filtered_videos[category] = valid_videos

# Flatten the video list from all categories
videos = [video for category in filtered_videos.values() for video in category]

def dynamic_categorize_videos(videos):
    categories = {}

    for video in videos:
        title = video['title']
        transcription = video.get('transcription', '')

        if not transcription:
            category = "Miscellaneous Educational Content"
        else:
            prompt = dynamic_prompt.format(title=title, transcription=transcription)
            response = dynamic_llm.generate([prompt])
            category = response.generations[0][0].text.strip()  # Access the text and strip it

        # Ensuring only valid categories are considered
        if category in predefined_categories:
            if category not in categories:
                categories[category] = []
            categories[category].append(video)
        else:
            # Handle unexpected categories
            if "Miscellaneous Educational Content" not in categories:
                categories["Miscellaneous Educational Content"] = []
            categories["Miscellaneous Educational Content"].append(video)

    return categories

# Categorize the videos
categorized_videos = dynamic_categorize_videos(videos)

# Print categorized videos
for category, vids in categorized_videos.items():
    print(f"\nCategory: {category}")
    for vid in vids:
        print(f" - {vid['title']}")
# Out:
# Category: Physics
#  - how bikes *actually* work
#  - falling ladders - why does this happen?
#  - world&#39;s roundest object
#  - microwaving grapes makes plasma
#  - this phone trick is impossible
#  - i call this the &#39;no, you don&#39;t&#39; law
#  - does pressure melt ice?
#  - world&#39;s strongest magnet!
#  - how a slinky falls in slow motion #shorts
#  - atomic theory
#  - backspin basketball flies off dam
#  - how does a boomerang work?
#  - can you solve this shadow illusion?
#  - anti-gravity wheel explained
#  - ice spikes explained
#  - misconceptions about temperature
#  - heisenberg&#39;s uncertainty principle explained
#  - can you go the speed of light?
#  - empty space is not empty
#  - how special relativity makes magnets work
#  - 4 revolutionary riddles
#  - 5 fun physics phenomena
#  - what is a force?
#  - explained: 5 fun physics phenomena
#  - option b - acceleration of a bungy jump
#  - how does a sailboat actually work?
#  - single photon interference
#  - will this go faster than light?
#  - misconceptions about falling objects
#  - is this what quantum mechanics looks like?
#  - why einstein thought nuclear weapons were impossible
#  - best film on newton&#39;s third law. ever.
#  - the brightest part of a shadow is in the middle
#  - how to make a quantum bit
#  - option c - acceleration of a bungy jump
#  - thomson&#39;s plum pudding model of the atom
#  - celsius made his thermometer upside down
#  - what is not random?
#  - schlieren imaging in color!
#  - this particle breaks time symmetry
#  - the absurdity of detecting gravitational waves
#  - your mass is not from the higgs boson
#  - spinning sphere of molten sodium
#  - 4 revolutionary riddles resolved!
#  - atomic rant
#  - slinky drop extended
#  - quantum entanglement &amp; spooky action at a distance
#  - option d - acceleration of a bungy jump
#  - the inverse leidenfrost effect
#  - the bullet block experiment
#  - the kg is dead, long live the kg
#  - what is gravity?
#  - the bizarre behavior of rotating bodies
#  - the big misconception about electricity
#  - world&#39;s roundest object!
#  - how to measure the tiniest forces in the universe
#  - buoyancy quiz
#  - 3 perplexing physics problems
#  - how we&#39;re redefining the kg
#  - parallel worlds probably exist. here’s why
#  - the surprising secret of synchronization
#  - how gravity actually works
#  - the real story of oppenheimer
#  - why no one has measured the speed of light
#  - the most misunderstood concept in physics
#  - buoyancy quiz
#  - three incorrect laws of motion
#  - radiation vs radioactive atoms
#  - misconceptions about falling objects
#  - gyroscopic precession
#  - something strange happens when you follow einstein&#39;s math
#  - radiation vs radioactive atoms
#  - world&#39;s strongest magnet!
#  - sparks from falling water: kelvin&#39;s thunderstorm
#  - slinky drop answer
#  - the science of curveballs
#  - a physics prof bet me $10,000 i&#39;m wrong
#  - imploding drum
#  - hydrodynamic levitation!
#  - how dangerous is a penny dropped from a skyscraper?
#  - how dangerous is a penny dropped from a skyscraper?
#  - can we really touch anything?
#  - epic slow-mo drum implosions!
#  - ice cutting experiment
#  - chain drop experiment
#  - in high jump, your centre of mass goes under the bar
#  - spinning tube trick
#  - how to see air currents
#  - what forces are acting on you?
#  - levitating barbecue! electromagnetic induction
#  - when is a bungee jumper&#39;s acceleration max?
#  - gravity (scientific version of john mayer&#39;s gravity)
#  - where does the sun get its energy?
#  - bullet block experiment result
#  - which hits the ground first?
#  - where does the sun get its energy?
#  - i rented a helicopter to settle a physics debate
#  - how does a slinky fall?
#  - chain drop answer 2
#  - microwaving grapes makes plasma
#  - nobel prize winner brian schmidt - physics 2011
#  - the original double slit experiment
#  - egg experiment to demonstrate inertia
#  - musical fire table!
#  - slinky drop
#  - science of laser hair removal in slow motion
#  - persistence of vision
#  - what is electricity? (are you gonna be my girl?)
#  - slow-mo non-newtonian fluid on a speaker
#  - ice cutting experiment
#  - bullet block explained!
#  - free higgs!
#  - galileo the scientific parrot
#  - the stickiest *non-sticky* material
#  - i waterproofed myself with aerogel!
#  - how does a wing actually work?
#  - world&#39;s first electric generator
#  - electromagnetic levitation quadcopter
#  - veritasium trailer
#  - world&#39;s heaviest weight
#  - how to make colour with holes
#  - the science of jetpacks and rockets!
#  - world&#39;s longest straw
#  - explained: beaker ball balance problem
#  - the ring on a chain trick
#  - the illusion only some can see
#  - what actually expands in an expanding universe?
#  - half the universe was missing... until now
#  - the universe is hostile to computers
#  - is there gravity in space?
#  - what’s in a candle flame?
#  - uranium: twisting the dragon&#39;s tail
#  - how damaging is radiation?
#  - how damaging is radiation?
#  - can you perceive acceleration?
#  - why are snowflakes like this?
#  - stringless yo-yo!
#
# Category: Geoscience
#  - raindrops aren&#39;t shaped like raindrops
#  - why does the earth spin?
#  - does water swirl the other way in the southern hemisphere?
#  - is glass a liquid?
#  - the terrifying real science of avalanches
#  - how does the earth spin?
#  - how long does it take for the earth to go around the sun?
#  - what causes the seasons?
#  - the damaged chernobyl reactor
#  - how were the pyramids built?
#  - inside the navy&#39;s indoor ocean
#  - what powers australia?
#  - inside japan’s earthquake simulator
#  - inside japan’s earthquake simulator
#  - should this lake exist?
#  - the most radioactive places on earth
#  - inside the svalbard seed vault
#  - these pools help support half the people on earth
#  - our greatest delusion
#  - the rainiest place on earth
#  - svalbard - the northernmost town on earth
#  - why are 96,000,000 black balls on this reservoir?
#  - why are 96,000,000 black balls on this reservoir?
#  - climate change is boring
#  - the truth about toilet swirl - southern hemisphere
#
# Category: General Science
#  - supercooled water - explained!
#  - misconceptions about heat
#  - most people don&#39;t know how bikes work
#  - the world in uv
#  - how we’re fooled by statistics
#  - what the fahrenheit?!
#  - experiments a cappella
#  - how kodak exposed nuclear testing
#  - the 4 things it takes to be an expert
#  - three awesome high school science projects
#  - how close we&#39;ve come to nuclear war
#  - why life seems to speed up as we age
#  - what the ultimate study on happiness reveals
#  - the science of thinking
#  - how much information?
#  - the problem with science communication
#  - the science of six degrees of separation
#  - the illusion of truth
#
# Category: Technology
#  - how does a quantum computer work?
#  - why robots that bend are better
#  - is america actually metric?
#  - world&#39;s highest jumping robot
#  - how to launch a nuclear missile
#  - i waterproofed myself with aerogel!
#  - world&#39;s lightest solid!
#  - the genius of 3d printed rockets
#  - magnetic micro-robots
#  - the remarkable story behind the most important algorithm of all time
#  - the stickiest *non-sticky* substance
#  - this unstoppable robot could save your life
#  - future computers will be radically different (analog computing)
#  - how quantum computers break the internet... starting now
#  - why you should want driverless cars on roads now
#  - how hidden technology transformed bowling
#  - this is why we can&#39;t have nice things
#  - the real moral dilemma of self-driving cars
#  - the threat of ai weapons
#  - how was video invented?
#  - why the future of cars is electric
#  - can you recover sound from images?
#  - can you recover sound from images?
#  - this toy can open any garage
#
# Category: Engineering
#  - anti-gravity wheel?
#  - 3 ways of seeing invisible air flow
#  - indestructible coating?!
#  - how japanese masters turn sand into swords
#  - indestructible coating?!
#  - world&#39;s first car!
#  - getting buried in concrete to explain how it works
#  - an affordable 3d-printed arm
#  - capitoltv&#39;s district voices - district 5: electric sparks from falling water
#  - flamethrower vs aerogel
#  - inside the navy&#39;s indoor ocean
#  - why machines that bend are better
#  - engineering with origami
#  - testing the us military’s worst idea
#  - how ultrasound can deactivate parts of the brain
#
# Category: Space
#  - the best test of general relativity (by 2 misplaced satellites)
#  - how nasa reinvented the wheel
#  - why do we launch rockets from florida?
#  - congress is about to make a huge mistake for astronomy #savechandra
#  - how far away is the moon? (the scale of the universe)
#  - why are astronauts weightless?
#  - how the quantum vacuum gave rise to galaxies
#  - what causes the phases of the moon?
#  - why metals spontaneously fuse together in space
#  - how to understand what black holes look like
#  - spinning black holes
#  - why apollo astronauts trained in nuclear bomb craters
#  - do people understand the scale of the universe?
#  - what happens if a star explodes near the earth?
#  - the universe is hostile to computers
#  - does planet 9 exist?
#  - an astronaut&#39;s view of earth
#  - how did they actually take this picture? (very long baseline interferometry)
#  - five firsts for mars insight
#  - neutron star merger gravitational waves and gamma rays
#  - how to clean up space junk
#  - five firsts for mars insight
#  - how to clean up space junk
#  - these are the asteroids to worry about
#  - new gravitational wave discovery!
#  - what causes the northern lights?
#  - first image of a black hole!
#  - what it’s like to watch a total solar eclipse
#  - mars 2020: nasa&#39;s next mission to mars
#  - 3 sources of water on the moon
#  - do aliens exist?
#  - northern lights from 100,000 ft!
#
# Category: Miscellaneous Educational Content
#  - chaos: the science of the butterfly effect
#  - a human being is a part of the whole
#  - a human being is a part of the whole
#  - are you lightest in the morning?
#  - can you swim in shade balls?
#  - my life story
#  - my life story
#  - supersized slow-mo slinky drop
#  - i buried myself in concrete to explain how it works
#  - would you take this bet?
#  - what game theory reveals about life, the universe, and everything
#  - what i wish i knew when i was younger
#  - is most published research wrong?
#  - the world depends on a collection of strange items. they&#39;re not cheap
#  - the illusion only some people can see
#  - clickbait is unreasonably effective
#  - sandwich bag fire starter
#  - why new years resolutions fail &amp; how to succeed
#  - i took an iq test to find out what it actually measures
#  - is dust mostly dead skin?
#  - do salt lamps work?
#  - how they caught the golden state killer
#  - what colour is most attractive?
#  - the most persistent myth
#  - clickbait is unreasonably effective
#  - facebook fraud
#  - khan academy and the effectiveness of science videos
#  - why boredom is good for you
#  - the most common cognitive bias
#  - is success luck or hard work?
#  - is success luck or hard work?
#  - q&amp;a + giveaway for 10 years on youtube
#  - q&amp;a + giveaway for 10 years on youtube
#  - post-truth: why facts don&#39;t matter anymore
#  - post-truth: why facts don&#39;t matter anymore
#  - the biggest myth in education
#  - the most controversial problem in philosophy
#  - can silence actually drive you crazy?
#
# Category: Mathematics
#  - the bayesian trap
#  - the most dangerous problem in math
#  - how an infinite hotel ran out of room
#  - the riddle that seems impossible even if you know the answer
#  - math&#39;s fundamental flaw
#  - how imaginary numbers were invented
#  - the oldest unsolved problem in math
#  - how one line in the oldest math text hinted at hidden universes
#  - this equation will change how you see the world (the logistic map)
#  - the infinite pattern that never repeats
#  - why is this number everywhere?
#  - the trillion dollar equation
#  - the bayesian trap
#  - mathematicians use numbers differently from the rest of us
#  - the simplest math problem no one can solve - collatz conjecture
#  - the sat question everyone got wrong
#
# Category: Biology
#  - how can trees be taller than 10m?
#  - 10 facts about great white sharks
#  - where do trees get their mass?
#  - how uv causes cancer and aging
#  - how do chameleons change color?
#  - why women are stripey
#  - your body&#39;s molecular machines
#  - how trees bend the laws of physics
#  - what actually causes dandruff?
#  - how cod saved the vikings
#  - what could survive an atomic bomb?
#  - is our food becoming less nutritious?
#  - i vacuum venom from the world&#39;s deadliest spider
#  - the longest-running evolution experiment
#  - why do venomous animals live in warm climates?
#  - what jumping spiders teach us about color
#  - can humans sense magnetic fields?
#  - why trees are taller than they need to be
#  - evolutionarily stable strategies ft. richard dawkins
#  - we tagged a great white shark!
#  - can you overdose on vitamins?
#  - how horses save humans from snakebites
#  - how to slow aging (and even reverse it)
#  - how long will you live?
#  - the sun sneeze gene
#  - these liquids look alive!
#  - do cell phones cause brain tumors?
#  - how a shark attack survivor invented cage diving
#  - koala encounters
#
# Category: Chemistry
#  - states of matter
#  - candle trick
#  - making liquid nitrogen from scratch!
#  - impress her with nanodiamonds
#  - what are atoms and isotopes?
#  - snatoms! the magnetic molecular modeling kit
#  - the hidden science of fireworks
#  - what&#39;s in a candle flame?
#  - making solid nitrogen!
#  - what is chemistry?
#  - what is chemistry?
#  - atomic bonding song
#  - the man who killed millions and saved billions
#  - i&#39;m atoms (scientific cover of jason mraz&#39;s i&#39;m yours)
#  - what is water made of?
#  - how to make graphene
#  - the man who killed millions and saved billions (clean version)

# %% [markdown]
# ## Creating Document for Pinecone

# %% [markdown]
# ### Chunking

# %%
# NEW TEST
import json
from transformers import BartTokenizer, BartForConditionalGeneration
from tqdm import tqdm

# Function to create a summary for each chunk using BART
def create_summary(text):
    inputs = tokenizer(text, max_length=1024, return_tensors='pt', truncation=True).to('cuda')
    summary_ids = model.generate(inputs['input_ids'], max_length=250, min_length=50, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# Custom function to split text into chunks with overlap
def custom_text_splitter(text, chunk_size=3000, chunk_overlap=150):
    chunks = []
    start = 0
    end = chunk_size

    while start < len(text):
        chunk = text[start:end]
        chunks.append(chunk)
        start = end - chunk_overlap
        end = start + chunk_size

    return chunks

# Function to chunk transcriptions and add context using the custom splitter
def chunk_transcriptions(videos, category, chunk_size=3000, chunk_overlap=150):
    chunks = []
    for video in tqdm(videos, desc="Processing Videos"):
        if 'transcription' in video:
            video_id = video["videoId"]
            transcription = video["transcription"]
            title = video["title"]
            description = video["description"]
            url = video["url"]
            published_at = video["published_at"]

            # Create document object with added context
            document = {
                "page_content": transcription,
                "metadata": {
                    "video_id": video_id,
                    "title": title,
                    "description": description,
                    "url": url,
                    "category": category,
                    "published_at": published_at
                }
            }

            # Use the custom text splitter to split the document into chunks
            chunked_texts = custom_text_splitter(document["page_content"], chunk_size, chunk_overlap)

            for i, chunk_content in enumerate(chunked_texts):
                summary = create_summary(chunk_content)

                # Add metadata to the chunk
                chunk = {
                    "page_content": chunk_content,
                    "metadata": {
                        "video_id": video_id,
                        "title": title,
                        "description": description,
                        "url": url,
                        "category": category,
                        "summary": summary,
                        "chunk_id": f"{video_id}_{i}",
                        "published_at": published_at
                    }
                }

                chunks.append(chunk)

    return chunks

# Function to process transcribed_videos in batches to avoid memory issues
def process_in_batches(filtered_videos, batch_size=20):
    all_chunks = []
    categories = list(filtered_videos.keys())

    for category in tqdm(categories, desc="Processing Categories"):
        videos = filtered_videos[category]

        # Split videos into batches
        for i in tqdm(range(0, len(videos), batch_size), desc="Processing Batches", leave=False):
            batch = videos[i:i+batch_size]

            # Chunk transcriptions and add context
            chunks = chunk_transcriptions(batch, category)

            # Accumulate chunks
            all_chunks.extend(chunks)

    return all_chunks

# Initialize the tokenizer and model for summarization
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large-cnn')
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large-cnn').to('cuda')

# ### Testing on a small category
# Process only the "Chemistry" category videos in batches to avoid memory issues
# chemistry_videos = categorized_videos.get("Chemistry", [])
# chunks = process_in_batches({"Chemistry": chemistry_videos}, batch_size=20)

chunks = process_in_batches(categorized_videos, batch_size=20)

# Output the number of chunks processed
print(f"Number of chunks processed: {len(chunks)}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Processing Categories:   0%|          | 0/10 [00:00<?, ?it/s]
# Processing Batches:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Processing Videos:   0%|          | 0/20 [00:00<?, ?it/s]
#
# Processing Videos:   5%|▌         | 1/20 [00:02<00:53,  2.79s/it]
#
# Processing Videos:  10%|█         | 2/20 [00:03<00:28,  1.56s/it]
#
# Processing Videos:  15%|█▌        | 3/20 [00:04<00:20,  1.19s/it]
#
# Processing Videos:  20%|██        | 4/20 [00:04<00:16,  1.01s/it]
#
# Processing Videos:  25%|██▌       | 5/20 [00:05<00:14,  1.07it/s]
#
# Processing Videos:  30%|███       | 6/20 [00:06<00:12,  1.14it/s]
#
# Processing Videos:  35%|███▌      | 7/20 [00:07<00:13,  1.04s/it]
#
# Processing Videos:  40%|████      | 8/20 [00:08<00:11,  1.03it/s]
#
# Processing Videos:  45%|████▌     | 9/20 [00:09<00:10,  1.07it/s]
#
# Processing Videos:  50%|█████     | 10/20 [00:10<00:09,  1.10it/s]
#
# Processing Videos:  55%|█████▌    | 11/20 [00:11<00:08,  1.05it/s]
#
# Processing Videos:  60%|██████    | 12/20 [00:12<00:06,  1.15it/s]
#
# Processing Videos:  65%|██████▌   | 13/20 [00:14<00:08,  1.15s/it]
#
# Processing Videos:  70%|███████   | 14/20 [00:15<00:08,  1.36s/it]
#
# Processing Videos:  75%|███████▌  | 15/20 [00:17<00:07,  1.46s/it]
#
# Processing Videos:  80%|████████  | 16/20 [00:19<00:06,  1.55s/it]
#
# Processing Videos:  85%|████████▌ | 17/20 [00:20<00:04,  1.58s/it]
#
# Processing Videos:  90%|█████████ | 18/20 [00:22<00:03,  1.57s/it]
#
# Processing Videos:  95%|█████████▌| 19/20 [00:24<00:01,  1.59s/it]
#
# Processing Videos: 100%|██████████| 20/20 [00:25<00:00,  1.29s/it]
#
# Processing Batches:  14%|█▍        | 1/7 [00:25<02:35, 25.88s/it]
#
# Processing Videos:   0%|          | 0/20 [00:00<?, ?it/s]
#
# Processing Videos:   5%|▌         | 1/20 [00:01<00:34,  1.81s/it]
#
# Processing Videos:  10%|█         | 2/20 [00:03<00:33,  1.85s/it]
#
# Processing Videos:  15%|█▌        | 3/20 [00:05<00:28,  1.70s/it]
#
# Processing Videos:  20%|██        | 4/20 [00:07<00:29,  1.86s/it]
#
# Processing Videos:  25%|██▌       | 5/20 [00:07<00:21,  1.43s/it]
#
# Processing Videos:  30%|███       | 6/20 [00:09<00:20,  1.44s/it]
#
# Processing Videos:  35%|███▌      | 7/20 [00:12<00:24,  1.89s/it]
#
# Processing Videos:  40%|████      | 8/20 [00:14<00:24,  2.07s/it]
#
# Processing Videos:  45%|████▌     | 9/20 [00:16<00:21,  1.96s/it]
#
# Processing Videos:  50%|█████     | 10/20 [00:18<00:21,  2.13s/it]
#
# Processing Videos:  55%|█████▌    | 11/20 [00:21<00:20,  2.29s/it]
#
# Processing Videos:  60%|██████    | 12/20 [00:23<00:17,  2.22s/it]
#
# Processing Videos:  65%|██████▌   | 13/20 [00:26<00:17,  2.51s/it]
#
# Processing Videos:  70%|███████   | 14/20 [00:29<00:15,  2.55s/it]
#
# Processing Videos:  75%|███████▌  | 15/20 [00:30<00:09,  1.98s/it]
#
# Processing Videos:  80%|████████  | 16/20 [00:30<00:06,  1.61s/it]
#
# Processing Videos:  85%|████████▌ | 17/20 [00:33<00:05,  1.99s/it]
#
# Processing Videos:  90%|█████████ | 18/20 [00:36<00:04,  2.20s/it]
#
# Processing Videos:  95%|█████████▌| 19/20 [00:39<00:02,  2.43s/it]
#
# Processing Videos: 100%|██████████| 20/20 [00:42<00:00,  2.15s/it]
#
# Processing Batches:  29%|██▊       | 2/7 [01:08<02:59, 35.94s/it]
#
# Processing Videos:   0%|          | 0/20 [00:00<?, ?it/s]
#
# Processing Videos:   5%|▌         | 1/20 [00:03<01:00,  3.18s/it]
#
# Processing Videos:  10%|█         | 2/20 [00:06<00:53,  2.97s/it]
#
# Processing Videos:  15%|█▌        | 3/20 [00:08<00:48,  2.88s/it]
#
# Processing Videos:  20%|██        | 4/20 [00:11<00:45,  2.84s/it]
#
# Processing Videos:  25%|██▌       | 5/20 [00:12<00:31,  2.10s/it]
#
# Processing Videos:  30%|███       | 6/20 [00:13<00:22,  1.64s/it]
#
# Processing Videos:  35%|███▌      | 7/20 [00:17<00:30,  2.38s/it]
#
# Processing Videos:  40%|████      | 8/20 [00:17<00:22,  1.89s/it]
#
# Processing Videos:  45%|████▌     | 9/20 [00:20<00:23,  2.13s/it]
#
# Processing Videos:  50%|█████     | 10/20 [00:21<00:16,  1.69s/it]
#
# Processing Videos:  55%|█████▌    | 11/20 [00:24<00:20,  2.25s/it]
#
# Processing Videos:  60%|██████    | 12/20 [00:25<00:14,  1.81s/it]
#
# Processing Videos:  65%|██████▌   | 13/20 [00:30<00:18,  2.71s/it]
#
# Processing Videos:  70%|███████   | 14/20 [00:34<00:19,  3.24s/it]
#
# Processing Videos:  75%|███████▌  | 15/20 [00:38<00:16,  3.27s/it]
#
# Processing Videos:  80%|████████  | 16/20 [00:43<00:15,  3.90s/it]
#
# Processing Videos:  85%|████████▌ | 17/20 [00:44<00:08,  2.99s/it]
#
# Processing Videos:  90%|█████████ | 18/20 [00:48<00:06,  3.22s/it]
#
# Processing Videos:  95%|█████████▌| 19/20 [00:52<00:03,  3.44s/it]
#
# Processing Videos: 100%|██████████| 20/20 [00:58<00:00,  2.93s/it]
#
# Processing Batches:  43%|████▎     | 3/7 [02:07<03:05, 46.27s/it]
#
# Processing Videos:   0%|          | 0/20 [00:00<?, ?it/s]
#
# Processing Videos:   5%|▌         | 1/20 [00:06<01:56,  6.11s/it]
#
# Processing Videos:  10%|█         | 2/20 [00:10<01:35,  5.33s/it]
#
# Processing Videos:  15%|█▌        | 3/20 [00:20<02:04,  7.32s/it]
#
# Processing Videos:  20%|██        | 4/20 [00:26<01:47,  6.73s/it]
#
# Processing Videos:  25%|██▌       | 5/20 [00:33<01:44,  6.94s/it]
#
# Processing Videos:  30%|███       | 6/20 [00:34<01:08,  4.87s/it]
#
# Processing Videos:  35%|███▌      | 7/20 [00:35<00:46,  3.59s/it]
#
# Processing Videos:  40%|████      | 8/20 [00:36<00:33,  2.78s/it]
#
# Processing Videos:  45%|████▌     | 9/20 [00:38<00:26,  2.39s/it]
#
# Processing Videos:  50%|█████     | 10/20 [00:40<00:22,  2.30s/it]
#
# Processing Videos:  55%|█████▌    | 11/20 [00:51<00:45,  5.06s/it]
#
# Processing Videos:  60%|██████    | 12/20 [00:52<00:30,  3.83s/it]
#
# Processing Videos:  65%|██████▌   | 13/20 [00:58<00:30,  4.39s/it]
#
# Processing Videos:  70%|███████   | 14/20 [01:00<00:21,  3.61s/it]
#
# Processing Videos:  75%|███████▌  | 15/20 [01:00<00:14,  2.80s/it]
#
# Processing Videos:  80%|████████  | 16/20 [01:02<00:10,  2.55s/it]
#
# Processing Videos:  85%|████████▌ | 17/20 [01:08<00:10,  3.47s/it]
#
# Processing Videos:  90%|█████████ | 18/20 [01:10<00:05,  2.94s/it]
#
# Processing Videos:  95%|█████████▌| 19/20 [01:12<00:02,  2.69s/it]
#
# Processing Videos: 100%|██████████| 20/20 [01:18<00:00,  3.95s/it]
#
# Processing Batches:  57%|█████▋    | 4/7 [03:26<02:57, 59.18s/it]
#
# Processing Videos:   0%|          | 0/20 [00:00<?, ?it/s]
#
# Processing Videos:   5%|▌         | 1/20 [00:06<02:06,  6.65s/it]
#
# Processing Videos:  10%|█         | 2/20 [00:09<01:15,  4.19s/it]
#
# Processing Videos:  15%|█▌        | 3/20 [00:10<00:51,  3.05s/it]
#
# Processing Videos:  20%|██        | 4/20 [00:11<00:34,  2.15s/it]
#
# Processing Videos:  25%|██▌       | 5/20 [00:12<00:25,  1.72s/it]
#
# Processing Videos:  30%|███       | 6/20 [00:14<00:22,  1.64s/it]
#
# Processing Videos:  35%|███▌      | 7/20 [00:14<00:17,  1.37s/it]
#
# Processing Videos:  40%|████      | 8/20 [00:16<00:19,  1.60s/it]
#
# Processing Videos:  45%|████▌     | 9/20 [00:17<00:14,  1.33s/it]
#
# Processing Videos:  50%|█████     | 10/20 [00:18<00:11,  1.18s/it]
#
# Processing Videos:  55%|█████▌    | 11/20 [00:19<00:09,  1.04s/it]
#
# Processing Videos:  60%|██████    | 12/20 [00:20<00:08,  1.07s/it]
#
# Processing Videos:  65%|██████▌   | 13/20 [00:22<00:08,  1.24s/it]
#
# Processing Videos:  70%|███████   | 14/20 [00:22<00:06,  1.11s/it]
#
# Processing Videos:  75%|███████▌  | 15/20 [00:23<00:05,  1.03s/it]
#
# Processing Videos:  80%|████████  | 16/20 [00:25<00:04,  1.22s/it]
#
# Processing Videos:  85%|████████▌ | 17/20 [00:29<00:06,  2.02s/it]
#
# Processing Videos:  90%|█████████ | 18/20 [00:30<00:03,  1.93s/it]
#
# Processing Videos:  95%|█████████▌| 19/20 [00:32<00:01,  1.83s/it]
#
# Processing Videos: 100%|██████████| 20/20 [00:35<00:00,  1.77s/it]
#
# Processing Batches:  71%|███████▏  | 5/7 [04:01<01:41, 50.64s/it]
#
# Processing Videos:   0%|          | 0/20 [00:00<?, ?it/s]
#
# Processing Videos:   5%|▌         | 1/20 [00:00<00:17,  1.09it/s]
#
# Processing Videos:  10%|█         | 2/20 [00:03<00:34,  1.92s/it]
#
# Processing Videos:  15%|█▌        | 3/20 [00:04<00:24,  1.43s/it]
#
# Processing Videos:  20%|██        | 4/20 [00:06<00:26,  1.63s/it]
#
# Processing Videos:  25%|██▌       | 5/20 [00:07<00:19,  1.31s/it]
#
# Processing Videos:  30%|███       | 6/20 [00:09<00:25,  1.85s/it]
#
# Processing Videos:  35%|███▌      | 7/20 [00:10<00:19,  1.53s/it]
#
# Processing Videos:  40%|████      | 8/20 [00:11<00:15,  1.29s/it]
#
# Processing Videos:  45%|████▌     | 9/20 [00:13<00:17,  1.59s/it]
#
# Processing Videos:  50%|█████     | 10/20 [00:14<00:13,  1.37s/it]
#
# Processing Videos:  55%|█████▌    | 11/20 [00:17<00:16,  1.80s/it]
#
# Processing Videos:  60%|██████    | 12/20 [00:18<00:12,  1.53s/it]
#
# Processing Videos:  65%|██████▌   | 13/20 [00:19<00:09,  1.35s/it]
#
# Processing Videos:  70%|███████   | 14/20 [00:20<00:06,  1.15s/it]
#
# Processing Videos:  75%|███████▌  | 15/20 [00:20<00:05,  1.01s/it]
#
# Processing Videos:  80%|████████  | 16/20 [00:21<00:03,  1.04it/s]
#
# Processing Videos:  85%|████████▌ | 17/20 [00:23<00:03,  1.24s/it]
#
# Processing Videos:  90%|█████████ | 18/20 [00:25<00:02,  1.41s/it]
#
# Processing Videos:  95%|█████████▌| 19/20 [00:26<00:01,  1.24s/it]
#
# Processing Videos: 100%|██████████| 20/20 [00:27<00:00,  1.39s/it]
#
# Processing Batches:  86%|████████▌ | 6/7 [04:29<00:42, 42.90s/it]
#
# Processing Videos:   0%|          | 0/17 [00:00<?, ?it/s]
#
# Processing Videos:   6%|▌         | 1/17 [00:01<00:26,  1.66s/it]
#
# Processing Videos:  12%|█▏        | 2/17 [00:04<00:36,  2.44s/it]
#
# Processing Videos:  18%|█▊        | 3/17 [00:07<00:35,  2.56s/it]
#
# Processing Videos:  24%|██▎       | 4/17 [00:08<00:24,  1.92s/it]
#
# Processing Videos:  29%|██▉       | 5/17 [00:09<00:18,  1.56s/it]
#
# Processing Videos:  35%|███▌      | 6/17 [00:09<00:14,  1.27s/it]
#
# Processing Videos:  41%|████      | 7/17 [00:14<00:22,  2.29s/it]
#
# Processing Videos:  47%|████▋     | 8/17 [00:18<00:27,  3.01s/it]
#
# Processing Videos:  53%|█████▎    | 9/17 [00:26<00:34,  4.31s/it]
#
# Processing Videos:  59%|█████▉    | 10/17 [00:26<00:22,  3.25s/it]
#
# Processing Videos:  65%|██████▍   | 11/17 [00:27<00:14,  2.48s/it]
#
# Processing Videos:  71%|███████   | 12/17 [00:28<00:10,  2.08s/it]
#
# Processing Videos:  76%|███████▋  | 13/17 [00:30<00:07,  1.91s/it]
#
# Processing Videos:  82%|████████▏ | 14/17 [00:31<00:05,  1.79s/it]
#
# Processing Videos:  88%|████████▊ | 15/17 [00:33<00:03,  1.80s/it]
#
# Processing Videos:  94%|█████████▍| 16/17 [00:38<00:02,  2.80s/it]
#
# Processing Videos: 100%|██████████| 17/17 [00:40<00:00,  2.38s/it]
#
# Processing Batches: 100%|██████████| 7/7 [05:10<00:00, 42.12s/it]
# Processing Categories:  10%|█         | 1/10 [05:10<46:32, 310.31s/it]
# Processing Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Processing Videos:   0%|          | 0/20 [00:00<?, ?it/s]
#
# Processing Videos:   5%|▌         | 1/20 [00:00<00:12,  1.49it/s]
#
# Processing Videos:  10%|█         | 2/20 [00:01<00:13,  1.38it/s]
#
# Processing Videos:  15%|█▌        | 3/20 [00:04<00:29,  1.73s/it]
#
# Processing Videos:  20%|██        | 4/20 [00:06<00:33,  2.08s/it]
#
# Processing Videos:  25%|██▌       | 5/20 [00:13<00:52,  3.53s/it]
#
# Processing Videos:  30%|███       | 6/20 [00:14<00:40,  2.93s/it]
#
# Processing Videos:  35%|███▌      | 7/20 [00:15<00:28,  2.18s/it]
#
# Processing Videos:  40%|████      | 8/20 [00:16<00:21,  1.79s/it]
#
# Processing Videos:  45%|████▌     | 9/20 [00:17<00:16,  1.47s/it]
#
# Processing Videos:  50%|█████     | 10/20 [00:19<00:17,  1.72s/it]
#
# Processing Videos:  55%|█████▌    | 11/20 [00:25<00:26,  2.92s/it]
#
# Processing Videos:  60%|██████    | 12/20 [00:26<00:20,  2.53s/it]
#
# Processing Videos:  65%|██████▌   | 13/20 [00:30<00:21,  3.03s/it]
#
# Processing Videos:  70%|███████   | 14/20 [00:35<00:20,  3.35s/it]
#
# Processing Videos:  75%|███████▌  | 15/20 [00:36<00:14,  2.89s/it]
#
# Processing Videos:  80%|████████  | 16/20 [00:39<00:11,  2.81s/it]
#
# Processing Videos:  85%|████████▌ | 17/20 [00:42<00:08,  2.76s/it]
#
# Processing Videos:  90%|█████████ | 18/20 [00:46<00:06,  3.31s/it]
#
# Processing Videos:  95%|█████████▌| 19/20 [00:48<00:02,  2.77s/it]
#
# Processing Videos: 100%|██████████| 20/20 [00:52<00:00,  2.64s/it]
#
# Processing Batches:  50%|█████     | 1/2 [00:52<00:52, 52.73s/it]
#
# Processing Videos:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Processing Videos:  20%|██        | 1/5 [00:02<00:10,  2.51s/it]
#
# Processing Videos:  40%|████      | 2/5 [00:05<00:09,  3.03s/it]
#
# Processing Videos:  60%|██████    | 3/5 [00:09<00:06,  3.21s/it]
#
# Processing Videos:  80%|████████  | 4/5 [00:10<00:02,  2.55s/it]
#
# Processing Videos: 100%|██████████| 5/5 [00:12<00:00,  2.52s/it]
#
# Processing Batches: 100%|██████████| 2/2 [01:05<00:00, 29.13s/it]
# Processing Categories:  20%|██        | 2/10 [06:15<22:09, 166.22s/it]
# Processing Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Processing Videos:   0%|          | 0/18 [00:00<?, ?it/s]
#
# Processing Videos:   6%|▌         | 1/18 [00:01<00:24,  1.46s/it]
#
# Processing Videos:  11%|█         | 2/18 [00:03<00:28,  1.80s/it]
#
# Processing Videos:  17%|█▋        | 3/18 [00:06<00:38,  2.56s/it]
#
# Processing Videos:  22%|██▏       | 4/18 [00:10<00:42,  3.02s/it]
#
# Processing Videos:  28%|██▊       | 5/18 [00:13<00:38,  2.99s/it]
#
# Processing Videos:  33%|███▎      | 6/18 [00:15<00:30,  2.56s/it]
#
# Processing Videos:  39%|███▉      | 7/18 [00:15<00:21,  1.93s/it]
#
# Processing Videos:  44%|████▍     | 8/18 [00:20<00:27,  2.72s/it]
#
# Processing Videos:  50%|█████     | 9/18 [00:26<00:33,  3.75s/it]
#
# Processing Videos:  56%|█████▌    | 10/18 [00:29<00:28,  3.57s/it]
#
# Processing Videos:  61%|██████    | 11/18 [00:34<00:27,  3.87s/it]
#
# Processing Videos:  67%|██████▋   | 12/18 [00:36<00:20,  3.43s/it]
#
# Processing Videos:  72%|███████▏  | 13/18 [00:42<00:20,  4.15s/it]
#
# Processing Videos:  78%|███████▊  | 14/18 [00:45<00:15,  3.99s/it]
#
# Processing Videos:  83%|████████▎ | 15/18 [00:47<00:09,  3.31s/it]
#
# Processing Videos:  89%|████████▉ | 16/18 [00:51<00:07,  3.59s/it]
#
# Processing Videos:  94%|█████████▍| 17/18 [00:55<00:03,  3.64s/it]
#
# Processing Videos: 100%|██████████| 18/18 [00:58<00:00,  3.24s/it]
#
# Processing Batches: 100%|██████████| 1/1 [00:58<00:00, 58.26s/it]
# Processing Categories:  30%|███       | 3/10 [07:13<13:38, 116.93s/it]
# Processing Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Processing Videos:   0%|          | 0/20 [00:00<?, ?it/s]
#
# Processing Videos:   5%|▌         | 1/20 [00:01<00:29,  1.55s/it]
#
# Processing Videos:  10%|█         | 2/20 [00:04<00:47,  2.65s/it]
#
# Processing Videos:  15%|█▌        | 3/20 [00:07<00:45,  2.70s/it]
#
# Processing Videos:  20%|██        | 4/20 [00:11<00:47,  2.99s/it]
#
# Processing Videos:  25%|██▌       | 5/20 [00:13<00:41,  2.80s/it]
#
# Processing Videos:  30%|███       | 6/20 [00:17<00:43,  3.13s/it]
#
# Processing Videos:  35%|███▌      | 7/20 [00:21<00:44,  3.42s/it]
#
# Processing Videos:  40%|████      | 8/20 [00:27<00:52,  4.34s/it]
#
# Processing Videos:  45%|████▌     | 9/20 [00:30<00:41,  3.73s/it]
#
# Processing Videos:  50%|█████     | 10/20 [00:37<00:49,  4.90s/it]
#
# Processing Videos:  55%|█████▌    | 11/20 [00:40<00:39,  4.43s/it]
#
# Processing Videos:  60%|██████    | 12/20 [00:45<00:34,  4.32s/it]
#
# Processing Videos:  65%|██████▌   | 13/20 [00:51<00:34,  4.87s/it]
#
# Processing Videos:  70%|███████   | 14/20 [00:59<00:34,  5.76s/it]
#
# Processing Videos:  75%|███████▌  | 15/20 [01:04<00:27,  5.58s/it]
#
# Processing Videos:  80%|████████  | 16/20 [01:11<00:24,  6.24s/it]
#
# Processing Videos:  85%|████████▌ | 17/20 [01:17<00:18,  6.03s/it]
#
# Processing Videos:  90%|█████████ | 18/20 [01:18<00:08,  4.45s/it]
#
# Processing Videos:  95%|█████████▌| 19/20 [01:20<00:03,  3.70s/it]
#
# Processing Videos: 100%|██████████| 20/20 [01:23<00:00,  4.19s/it]
#
# Processing Batches:  50%|█████     | 1/2 [01:23<01:23, 83.73s/it]
#
# Processing Videos:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Processing Videos:  25%|██▌       | 1/4 [00:01<00:05,  1.78s/it]
#
# Processing Videos:  50%|█████     | 2/4 [00:04<00:04,  2.26s/it]
#
# Processing Videos:  75%|███████▌  | 3/4 [00:06<00:02,  2.41s/it]
#
# Processing Videos: 100%|██████████| 4/4 [00:10<00:00,  2.73s/it]
#
# Processing Batches: 100%|██████████| 2/2 [01:34<00:00, 40.91s/it]
# Processing Categories:  40%|████      | 4/10 [08:48<10:48, 108.15s/it]
# Processing Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Processing Videos:   0%|          | 0/15 [00:00<?, ?it/s]
#
# Processing Videos:   7%|▋         | 1/15 [00:02<00:28,  2.05s/it]
#
# Processing Videos:  13%|█▎        | 2/15 [00:09<01:05,  5.00s/it]
#
# Processing Videos:  20%|██        | 3/15 [00:09<00:36,  3.06s/it]
#
# Processing Videos:  27%|██▋       | 4/15 [00:16<00:50,  4.61s/it]
#
# Processing Videos:  33%|███▎      | 5/15 [00:18<00:35,  3.56s/it]
#
# Processing Videos:  40%|████      | 6/15 [00:21<00:29,  3.23s/it]
#
# Processing Videos:  47%|████▋     | 7/15 [00:27<00:33,  4.18s/it]
#
# Processing Videos:  53%|█████▎    | 8/15 [00:30<00:26,  3.73s/it]
#
# Processing Videos:  60%|██████    | 9/15 [00:30<00:16,  2.81s/it]
#
# Processing Videos:  67%|██████▋   | 10/15 [00:34<00:15,  3.10s/it]
#
# Processing Videos:  73%|███████▎  | 11/15 [00:40<00:15,  3.89s/it]
#
# Processing Videos:  80%|████████  | 12/15 [00:43<00:11,  3.76s/it]
#
# Processing Videos:  87%|████████▋ | 13/15 [00:49<00:08,  4.28s/it]
#
# Processing Videos:  93%|█████████▎| 14/15 [00:55<00:04,  4.92s/it]
#
# Processing Videos: 100%|██████████| 15/15 [00:58<00:00,  3.88s/it]
#
# Processing Batches: 100%|██████████| 1/1 [00:58<00:00, 58.18s/it]
# Processing Categories:  50%|█████     | 5/10 [09:46<07:30, 90.13s/it]
# Processing Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Processing Videos:   0%|          | 0/20 [00:00<?, ?it/s]
#
# Processing Videos:   5%|▌         | 1/20 [00:03<01:10,  3.71s/it]
#
# Processing Videos:  10%|█         | 2/20 [00:10<01:42,  5.69s/it]
#
# Processing Videos:  15%|█▌        | 3/20 [00:11<00:58,  3.42s/it]
#
# Processing Videos:  20%|██        | 4/20 [00:12<00:37,  2.36s/it]
#
# Processing Videos:  25%|██▌       | 5/20 [00:13<00:27,  1.85s/it]
#
# Processing Videos:  30%|███       | 6/20 [00:14<00:21,  1.51s/it]
#
# Processing Videos:  35%|███▌      | 7/20 [00:15<00:20,  1.60s/it]
#
# Processing Videos:  40%|████      | 8/20 [00:17<00:19,  1.65s/it]
#
# Processing Videos:  45%|████▌     | 9/20 [00:19<00:20,  1.85s/it]
#
# Processing Videos:  50%|█████     | 10/20 [00:23<00:24,  2.43s/it]
#
# Processing Videos:  55%|█████▌    | 11/20 [00:27<00:27,  3.02s/it]
#
# Processing Videos:  60%|██████    | 12/20 [00:31<00:25,  3.15s/it]
#
# Processing Videos:  65%|██████▌   | 13/20 [00:35<00:24,  3.52s/it]
#
# Processing Videos:  70%|███████   | 14/20 [00:41<00:24,  4.12s/it]
#
# Processing Videos:  75%|███████▌  | 15/20 [00:48<00:25,  5.04s/it]
#
# Processing Videos:  80%|████████  | 16/20 [00:52<00:18,  4.69s/it]
#
# Processing Videos:  85%|████████▌ | 17/20 [00:54<00:11,  3.99s/it]
#
# Processing Videos:  90%|█████████ | 18/20 [01:00<00:09,  4.64s/it]
#
# Processing Videos:  95%|█████████▌| 19/20 [01:02<00:03,  3.77s/it]
#
# Processing Videos: 100%|██████████| 20/20 [01:04<00:00,  3.22s/it]
#
# Processing Batches:  50%|█████     | 1/2 [01:04<01:04, 64.49s/it]
#
# Processing Videos:   0%|          | 0/12 [00:00<?, ?it/s]
#
# Processing Videos:   8%|▊         | 1/12 [00:01<00:17,  1.62s/it]
#
# Processing Videos:  17%|█▋        | 2/12 [00:03<00:16,  1.69s/it]
#
# Processing Videos:  25%|██▌       | 3/12 [00:05<00:15,  1.67s/it]
#
# Processing Videos:  33%|███▎      | 4/12 [00:11<00:27,  3.44s/it]
#
# Processing Videos:  42%|████▏     | 5/12 [00:13<00:20,  2.95s/it]
#
# Processing Videos:  50%|█████     | 6/12 [00:15<00:15,  2.57s/it]
#
# Processing Videos:  58%|█████▊    | 7/12 [00:16<00:11,  2.32s/it]
#
# Processing Videos:  67%|██████▋   | 8/12 [00:17<00:07,  1.85s/it]
#
# Processing Videos:  75%|███████▌  | 9/12 [00:20<00:06,  2.03s/it]
#
# Processing Videos:  83%|████████▎ | 10/12 [00:22<00:04,  2.22s/it]
#
# Processing Videos:  92%|█████████▏| 11/12 [00:24<00:02,  2.18s/it]
#
# Processing Videos: 100%|██████████| 12/12 [00:26<00:00,  2.22s/it]
#
# Processing Batches: 100%|██████████| 2/2 [01:31<00:00, 42.22s/it]
# Processing Categories:  60%|██████    | 6/10 [11:17<06:01, 90.48s/it]
# Processing Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Processing Videos:   0%|          | 0/20 [00:00<?, ?it/s]
#
# Processing Videos:   5%|▌         | 1/20 [00:04<01:24,  4.46s/it]
#
# Processing Videos:  10%|█         | 2/20 [00:05<00:41,  2.30s/it]
#
# Processing Videos:  15%|█▌        | 3/20 [00:06<00:27,  1.60s/it]
#
# Processing Videos:  20%|██        | 4/20 [00:08<00:32,  2.01s/it]
#
# Processing Videos:  25%|██▌       | 5/20 [00:10<00:31,  2.12s/it]
#
# Processing Videos:  30%|███       | 6/20 [00:14<00:36,  2.60s/it]
#
# Processing Videos:  35%|███▌      | 7/20 [00:18<00:37,  2.91s/it]
#
# Processing Videos:  40%|████      | 8/20 [00:18<00:26,  2.24s/it]
#
# Processing Videos:  45%|████▌     | 9/20 [00:19<00:20,  1.84s/it]
#
# Processing Videos:  50%|█████     | 10/20 [00:22<00:21,  2.12s/it]
#
# Processing Videos:  55%|█████▌    | 11/20 [00:29<00:32,  3.61s/it]
#
# Processing Videos:  60%|██████    | 12/20 [00:33<00:29,  3.66s/it]
#
# Processing Videos:  65%|██████▌   | 13/20 [00:37<00:26,  3.84s/it]
#
# Processing Videos:  70%|███████   | 14/20 [00:42<00:25,  4.17s/it]
#
# Processing Videos:  75%|███████▌  | 15/20 [00:47<00:21,  4.30s/it]
#
# Processing Videos:  80%|████████  | 16/20 [00:52<00:19,  4.77s/it]
#
# Processing Videos:  85%|████████▌ | 17/20 [00:55<00:12,  4.08s/it]
#
# Processing Videos:  90%|█████████ | 18/20 [00:59<00:07,  3.95s/it]
#
# Processing Videos:  95%|█████████▌| 19/20 [01:07<00:05,  5.23s/it]
#
# Processing Videos: 100%|██████████| 20/20 [01:12<00:00,  3.61s/it]
#
# Processing Batches:  50%|█████     | 1/2 [01:12<01:12, 72.11s/it]
#
# Processing Videos:   0%|          | 0/18 [00:00<?, ?it/s]
#
# Processing Videos:   6%|▌         | 1/18 [00:04<01:16,  4.48s/it]
#
# Processing Videos:  11%|█         | 2/18 [00:10<01:25,  5.37s/it]
#
# Processing Videos:  17%|█▋        | 3/18 [00:11<00:50,  3.34s/it]
#
# Processing Videos:  22%|██▏       | 4/18 [00:13<00:41,  2.93s/it]
#
# Processing Videos:  28%|██▊       | 5/18 [00:19<00:51,  3.99s/it]
#
# Processing Videos:  33%|███▎      | 6/18 [00:23<00:45,  3.81s/it]
#
# Processing Videos:  39%|███▉      | 7/18 [00:25<00:36,  3.28s/it]
#
# Processing Videos:  44%|████▍     | 8/18 [00:27<00:29,  2.93s/it]
#
# Processing Videos:  50%|█████     | 9/18 [00:29<00:23,  2.56s/it]
#
# Processing Videos:  56%|█████▌    | 10/18 [00:33<00:25,  3.18s/it]
#
# Processing Videos:  61%|██████    | 11/18 [00:38<00:25,  3.60s/it]
#
# Processing Videos:  67%|██████▋   | 12/18 [00:42<00:22,  3.67s/it]
#
# Processing Videos:  72%|███████▏  | 13/18 [00:45<00:18,  3.70s/it]
#
# Processing Videos:  78%|███████▊  | 14/18 [00:51<00:17,  4.38s/it]
#
# Processing Videos:  83%|████████▎ | 15/18 [00:57<00:14,  4.85s/it]
#
# Processing Videos:  89%|████████▉ | 16/18 [01:02<00:09,  4.72s/it]
#
# Processing Videos:  94%|█████████▍| 17/18 [01:05<00:04,  4.43s/it]
#
# Processing Videos: 100%|██████████| 18/18 [01:08<00:00,  3.83s/it]
#
# Processing Batches: 100%|██████████| 2/2 [02:21<00:00, 70.22s/it]
# Processing Categories:  70%|███████   | 7/10 [13:38<05:20, 107.00s/it]
# Processing Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Processing Videos:   0%|          | 0/16 [00:00<?, ?it/s]
#
# Processing Videos:   6%|▋         | 1/16 [00:03<00:55,  3.67s/it]
#
# Processing Videos:  12%|█▎        | 2/16 [00:04<00:27,  1.98s/it]
#
# Processing Videos:  19%|█▉        | 3/16 [00:06<00:24,  1.89s/it]
#
# Processing Videos:  25%|██▌       | 4/16 [00:10<00:36,  3.00s/it]
#
# Processing Videos:  31%|███▏      | 5/16 [00:20<00:56,  5.18s/it]
#
# Processing Videos:  38%|███▊      | 6/16 [00:27<01:00,  6.10s/it]
#
# Processing Videos:  44%|████▍     | 7/16 [00:36<01:02,  6.92s/it]
#
# Processing Videos:  50%|█████     | 8/16 [00:46<01:02,  7.82s/it]
#
# Processing Videos:  56%|█████▋    | 9/16 [00:52<00:51,  7.37s/it]
#
# Processing Videos:  62%|██████▎   | 10/16 [00:59<00:42,  7.08s/it]
#
# Processing Videos:  69%|██████▉   | 11/16 [01:05<00:33,  6.74s/it]
#
# Processing Videos:  75%|███████▌  | 12/16 [01:13<00:28,  7.16s/it]
#
# Processing Videos:  81%|████████▏ | 13/16 [01:16<00:18,  6.11s/it]
#
# Processing Videos:  88%|████████▊ | 14/16 [01:27<00:14,  7.47s/it]
#
# Processing Videos:  94%|█████████▍| 15/16 [01:33<00:06,  6.96s/it]
#
# Processing Videos: 100%|██████████| 16/16 [01:37<00:00,  6.12s/it]
#
# Processing Batches: 100%|██████████| 1/1 [01:37<00:00, 97.98s/it]
# Processing Categories:  80%|████████  | 8/10 [15:16<03:28, 104.13s/it]
# Processing Batches:   0%|          | 0/2 [00:00<?, ?it/s]
#
# Processing Videos:   0%|          | 0/20 [00:00<?, ?it/s]
#
# Processing Videos:   5%|▌         | 1/20 [00:01<00:34,  1.84s/it]
#
# Processing Videos:  10%|█         | 2/20 [00:03<00:31,  1.76s/it]
#
# Processing Videos:  15%|█▌        | 3/20 [00:05<00:31,  1.84s/it]
#
# Processing Videos:  20%|██        | 4/20 [00:07<00:28,  1.76s/it]
#
# Processing Videos:  25%|██▌       | 5/20 [00:09<00:31,  2.12s/it]
#
# Processing Videos:  30%|███       | 6/20 [00:11<00:28,  2.00s/it]
#
# Processing Videos:  35%|███▌      | 7/20 [00:13<00:24,  1.88s/it]
#
# Processing Videos:  40%|████      | 8/20 [00:15<00:25,  2.11s/it]
#
# Processing Videos:  45%|████▌     | 9/20 [00:18<00:24,  2.26s/it]
#
# Processing Videos:  50%|█████     | 10/20 [00:21<00:23,  2.35s/it]
#
# Processing Videos:  55%|█████▌    | 11/20 [00:21<00:16,  1.89s/it]
#
# Processing Videos:  60%|██████    | 12/20 [00:24<00:16,  2.04s/it]
#
# Processing Videos:  65%|██████▌   | 13/20 [00:27<00:16,  2.29s/it]
#
# Processing Videos:  70%|███████   | 14/20 [00:32<00:18,  3.08s/it]
#
# Processing Videos:  75%|███████▌  | 15/20 [00:35<00:15,  3.16s/it]
#
# Processing Videos:  80%|████████  | 16/20 [00:43<00:18,  4.67s/it]
#
# Processing Videos:  85%|████████▌ | 17/20 [00:46<00:12,  4.29s/it]
#
# Processing Videos:  90%|█████████ | 18/20 [00:48<00:07,  3.51s/it]
#
# Processing Videos:  95%|█████████▌| 19/20 [00:50<00:02,  2.98s/it]
#
# Processing Videos: 100%|██████████| 20/20 [00:52<00:00,  2.61s/it]
#
# Processing Batches:  50%|█████     | 1/2 [00:52<00:52, 52.21s/it]
#
# Processing Videos:   0%|          | 0/9 [00:00<?, ?it/s]
#
# Processing Videos:  11%|█         | 1/9 [00:01<00:14,  1.75s/it]
#
# Processing Videos:  22%|██▏       | 2/9 [00:06<00:26,  3.73s/it]
#
# Processing Videos:  33%|███▎      | 3/9 [00:12<00:27,  4.59s/it]
#
# Processing Videos:  44%|████▍     | 4/9 [00:14<00:17,  3.46s/it]
#
# Processing Videos:  56%|█████▌    | 5/9 [00:15<00:11,  2.78s/it]
#
# Processing Videos:  67%|██████▋   | 6/9 [00:17<00:07,  2.39s/it]
#
# Processing Videos:  78%|███████▊  | 7/9 [00:20<00:04,  2.46s/it]
#
# Processing Videos:  89%|████████▉ | 8/9 [00:22<00:02,  2.51s/it]
#
# Processing Videos: 100%|██████████| 9/9 [00:23<00:00,  2.61s/it]
#
# Processing Batches: 100%|██████████| 2/2 [01:15<00:00, 35.34s/it]
# Processing Categories:  90%|█████████ | 9/10 [16:32<01:35, 95.26s/it]
# Processing Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Processing Videos:   0%|          | 0/17 [00:00<?, ?it/s]
#
# Processing Videos:   6%|▌         | 1/17 [00:01<00:25,  1.60s/it]
#
# Processing Videos:  12%|█▏        | 2/17 [00:02<00:18,  1.27s/it]
#
# Processing Videos:  18%|█▊        | 3/17 [00:06<00:32,  2.32s/it]
#
# Processing Videos:  24%|██▎       | 4/17 [00:07<00:22,  1.75s/it]
#
# Processing Videos:  29%|██▉       | 5/17 [00:07<00:17,  1.42s/it]
#
# Processing Videos:  35%|███▌      | 6/17 [00:09<00:16,  1.53s/it]
#
# Processing Videos:  41%|████      | 7/17 [00:18<00:37,  3.79s/it]
#
# Processing Videos:  47%|████▋     | 8/17 [00:18<00:25,  2.82s/it]
#
# Processing Videos:  53%|█████▎    | 9/17 [00:19<00:17,  2.19s/it]
#
# Processing Videos:  59%|█████▉    | 10/17 [00:20<00:12,  1.75s/it]
#
# Processing Videos:  65%|██████▍   | 11/17 [00:21<00:08,  1.45s/it]
#
# Processing Videos:  71%|███████   | 12/17 [00:21<00:06,  1.25s/it]
#
# Processing Videos:  76%|███████▋  | 13/17 [00:27<00:09,  2.42s/it]
#
# Processing Videos:  82%|████████▏ | 14/17 [00:27<00:05,  1.93s/it]
#
# Processing Videos:  88%|████████▊ | 15/17 [00:28<00:03,  1.59s/it]
#
# Processing Videos:  94%|█████████▍| 16/17 [00:29<00:01,  1.39s/it]
#
# Processing Videos: 100%|██████████| 17/17 [00:34<00:00,  2.01s/it]
#
# Processing Batches: 100%|██████████| 1/1 [00:34<00:00, 34.26s/it]
# Processing Categories: 100%|██████████| 10/10 [17:06<00:00, 102.70s/it]
# Number of chunks processed: 1141

# %%
# Inspect the results
for chunk in chunks[:20]:  # Display some chunks for inspection
    print(f"Chunk ID: {chunk['metadata']['chunk_id']}")
    print(f"Video ID: {chunk['metadata']['video_id']}")
    print(f"Title: {chunk['metadata']['title']}")
    print(f"Description: {chunk['metadata']['description']}")
    print(f"Category: {chunk['metadata']['category']}")
    print(f"Published At: {chunk['metadata']['published_at']}")
    print(f"Summary: {chunk['metadata']['summary']}")
    print(f"Chunk Content: {chunk['page_content'][:500]}...")  # Display the first 500 characters of the chunk
    print("\n" + "="*80 + "\n")
# Out:
# Chunk ID: scliyWrN7mk_0
# Video ID: scliyWrN7mk
# Title: how bikes *actually* work
# Description: why are bicycles stable? the most common answer is gyroscopic effects, but this is not right.
# Category: Physics
# Published At: 2024-04-17T16:20:50Z
# Summary: Bikes are stable without riders because they're cleverly designed to steer themselves. If they start falling to one side, the handlebars turn in that direction to steer the wheels back underneath them. Just watch what happens when we lock the handle bars completely, so you can only go straight ahead.
# Chunk Content: How do bikes without riders stay upright? As long as a bike is moving with sufficient speed, it can keep coasting indefinitely. But it turned out the ground where we went to test this effect was really bumpy. But the bike still manages to absorb all these perturbations. and remain stable. So how does it do this? I think most people believe it's the wheels spinning that creates some sort of gyroscopic effect that resists falling over. Just like in this demonstration of gyroscopic precession, the ...
#
# ================================================================================
#
# Chunk ID: n8WxkqMRgS4_0
# Video ID: n8WxkqMRgS4
# Title: falling ladders - why does this happen?
# Description: what happens when a chain ladder lands on a table? great video and concept by andy ruina. let me know if you want me to ...
# Category: Physics
# Published At: 2023-01-12T17:24:24Z
# Summary: Two chain ladders were dropped at exactly the same time by Cornell professor Andy Ruena. So which one will fall faster? The free-falling ladder, the one that hits the table, Or will they both fall at the same rate? Now why did that happen?
# Chunk Content: These two chain ladders were dropped at exactly the same time by Cornell professor Andy Ruena. The one on the right remains in freefall, but the one on the left will hit a table. So which one will fall faster? The free-falling ladder, the one that hits the table, Or will they both fall at the same rate? Now why did that happen?...
#
# ================================================================================
#
# Chunk ID: uDeQB9OkoXY_0
# Video ID: uDeQB9OkoXY
# Title: world&#39;s roundest object
# Description: this silicon sphere was made to redefine the kilogram.
# Category: Physics
# Published At: 2023-02-19T20:44:41Z
# Summary: If you scaled it up to the size of the earth, there would be no mountain or valley bigger than 10 meters. It was made out of a single crystal of pure silicon-28. The raw material cost more than a million euros. Its purpose was to help redefine what a kilogram actually is.
# Chunk Content: This is the world's roundest object. If you scaled it up to the size of the earth, there would be no mountain or valley bigger than 10 meters. It was made out of a single crystal of pure silicon-28. The raw material cost more than a million euros, and its purpose was to help redefine what a kilogram actually is....
#
# ================================================================================
#
# Chunk ID: LY6xeFpBeMQ_0
# Video ID: LY6xeFpBeMQ
# Title: microwaving grapes makes plasma
# Description:
# Category: Physics
# Published At: 2023-02-25T17:39:47Z
# Summary: If you take a grape and cut it almost completely in half and put it in the microwave you can make some plasma. You don't need to cut the grapes in half. Two grapes placed side by side will make this effect work as long as they stay in contact.
# Chunk Content: If you take a grape and cut it almost completely in half and put it in the microwave you can make some plasma. Go the laws of physics! You don't need to cut the grapes in half. Two grapes placed side by side will make this effect work as long as they stay in contact. Now with the very strong electromagnetic fields at the intersection of the two grapes What you can get is some sparks, some breakdown of air. That is, the electric fields are strong enough that they ionize the air creating those spa...
#
# ================================================================================
#
# Chunk ID: WKvAsz3RoRE_0
# Video ID: WKvAsz3RoRE
# Title: this phone trick is impossible
# Description: it all depends on the way you flip it. #science #physics #scienceexperiment for more videos like this, subscribe to @veritasium.
# Category: Physics
# Published At: 2024-05-17T15:39:46Z
# Summary: If you do it in this direction, it's pretty easy, it stays nicely aligned. If you spin it along its short axis, you'll also find it spins very well. But, if you try to flip your phone end over end like this, you can't do it cleanly.
# Chunk Content: Have you ever tried to spin your phone? If you do it in this direction, it's pretty easy, it stays nicely aligned. If you spin it along its short axis, you'll also find it spins very well. But, if you try to flip your phone end over end like this, you can't do it cleanly. The phone will never flip, simply end over end, without also rotating in one of the other directions. So why does this happen?...
#
# ================================================================================
#
# Chunk ID: 2FLqOI9jw-E_0
# Video ID: 2FLqOI9jw-E
# Title: i call this the &#39;no, you don&#39;t&#39; law
# Description: lenz's law states that the direction of the induced current will oppose the change in flux that created it. here's how that looks in ...
# Category: Physics
# Published At: 2024-04-10T17:11:15Z
# Summary: I like to think of Lenza's Law as the no you don't law, because whatever you try to do, nature acts to oppose you. In this case, a south magnetic pole is induced under the plate, attracting it back to the magnet. This is actually insanely difficult.
# Chunk Content: I like to think of Lenza's Law as the no you don't law, because whatever you try to do, nature acts to oppose you. If the plate is falling, eddy currents are induced to slow its descent. But if you try to pick up the plate, nature also says no you don't. In this case, a south magnetic pole is induced under the plate, attracting it back to the magnet. This is actually insanely difficult. Oh my goodness. You're strong like bull. No matter how hard I tried to push the plate down, it just wouldn't g...
#
# ================================================================================
#
# Chunk ID: gM3zP72-rJE_0
# Video ID: gM3zP72-rJE
# Title: does pressure melt ice?
# Description: when pressure is applied to ice, its melting point is reduced so it turns to water. when the pressure is removed, however, it turns ...
# Category: Physics
# Published At: 2011-08-14T02:49:29Z
# Summary: I'm going to try to demonstrate something called regulation, which is where you provide a pressure onto ice and that turns it into water, but after that pressure is removed it freezes again. So in order to demonstrate this I've taken apart the high E string from my guitar. I chose the E string because it's thinner than a G string and that's important. And I've weighted it with these two bottles of water. When I apply the string across the ice we should see the wire start to cut through the ice and perform the regulation of the ice.
# Chunk Content: I'm going to try to demonstrate something called regulation, which is where you provide a pressure onto ice and that turns it into water, but after that pressure is removed it freezes again. So in order to demonstrate this I've taken apart the high E string from my guitar I chose the E string because it's thinner than a G string and that's important. And I've weighted it with these two bottles of water. When I apply the string across the ice we should see the wire start to cut through the ice an...
#
# ================================================================================
#
# Chunk ID: ov_7HT8bbX4_0
# Video ID: ov_7HT8bbX4
# Title: world&#39;s strongest magnet!
# Description: the world's strongest magnet is a million times stronger than earth's magnetic field.
# Category: Physics
# Published At: 2024-02-21T17:22:53Z
# Summary: This is the world's strongest magnet, capable of sucking objects in, generating electric current, and levitating non-magnetic objects. This electromagnet creates a magnetic field of 45 Tesla, so nearly a million times Earth's magnetic field. We're going to experiment with the magnetic field that extends above and around the magnet on this platform.
# Chunk Content: This is the world's strongest magnet, capable of sucking objects in, generating electric current, and levitating non-magnetic objects. For reference, the magnetic field of the Earth is 0.00005. This electromagnet creates a magnetic field of 45 Tesla, so nearly a million times Earth's magnetic field. We're going to experiment with the magnetic field that extends above and around the magnet on this platform. We cut open a Nerf football and put in a couple steel washers, and sure enough, it's easy ...
#
# ================================================================================
#
# Chunk ID: k5s1cMNTmGs_0
# Video ID: k5s1cMNTmGs
# Title: how a slinky falls in slow motion #shorts
# Description: this is not just true of slinkies - if you release a steel rod from the top, the top really starts falling before the bottom. if you hit a ...
# Category: Physics
# Published At: 2021-07-19T20:48:32Z
# Summary: If you drop a slinky dangling under its own weight, the bottom won't start falling until the whole slinky has collapsed. This is because each coil is stretched to support the weight of everything beneath it. In order for one coil to fall, it needs the coil above it to collapse and so on all the way up to the top.
# Chunk Content: If you drop a slinky dangling under its own weight, the bottom won't start falling until the whole slinky has collapsed. This is because each coil is stretched to support the weight of everything beneath it. So in order for one coil to fall, it needs the coil above it. to collapse and so on all the way up to the top. It's like a row of dominoes where the tension released at the top cascades down the slinky and this takes some time. This is the longest slinky I had access to and what's cool about...
#
# ================================================================================
#
# Chunk ID: U2g1H5wPmUE_0
# Video ID: U2g1H5wPmUE
# Title: atomic theory
# Description: this is the first veritasium science video. it addresses one of the most fundamental concepts in science: the idea that all things are ...
# Category: Physics
# Published At: 2011-01-07T10:53:55Z
# Summary: Richard Feynman asked which statement would contain the most scientific information for future generations. His conclusion was that it is the Atomic Hypothesis. The atomic hypothesis states that all things are made up of atoms, tiny particles in perpetual motion. That statement is incredibly important to understand if you want to understand most of the rest of science.
# Chunk Content: Hi, and welcome to Veritasium, an online science video blog. I'd like to take on scientific topics all the way from the simplest to the most complex. So, a good One place to start, I think, is with a problem considered by a famous physicist, Richard Feynman. He asked, if all the world's scientific information except for one sentence were destroyed in some cataclysmic event. Which single statement would contain the most scientific information for future generations? His conclusion was that it is ...
#
# ================================================================================
#
# Chunk ID: 2OSrvzNW9FE_0
# Video ID: 2OSrvzNW9FE
# Title: backspin basketball flies off dam
# Description: how far would a basketball with backspin go? rotor wing experimental aircraft: https://youtu.be/ra8y6ggotwy e-ship 1: ...
# Category: Physics
# Published At: 2015-07-15T15:00:01Z
# Summary: The Magnus effect affects all rotating balls or cylinders as they fly through the air. As the basketball picks up speed, air on the front side of the ball is going in the same direction as its spin and therefore it gets dragged along with the ball and deflected back. The net result is the ball pushes air one way so the air applies an equal force on the ball the other way.
# Chunk Content: Recently, some friends of mine went to the Gordon Dam in Tasmania, which is 126.5 meters, or 415 feet high. Then they dropped a basketball over the edge. You can see that the basketball gets pushed around a bit by the breeze, but it lands basically right below where it was dropped. Now watch what happens when they drop another basketball, but this time with a bit of backspin. Whoa, look at that go! This is Brett who just threw it. I literally just dropped it with a bit of spin like I didn't even...
#
# ================================================================================
#
# Chunk ID: ADJKsLEAOHo_0
# Video ID: ADJKsLEAOHo
# Title: how does a boomerang work?
# Description: a boomerang can execute its unique roundtrip flight by making use of three fundamental physics principles: lift, relative velocity, ...
# Category: Physics
# Published At: 2012-08-17T10:46:58Z
# Summary: How does a boomerang work? Well, it relies on three fundamental principles. Lift, relative velocity, and gyroscopic precession. Although we usually associate them with Australia, they've also been found in places like ancient Egypt and Europe.
# Chunk Content: How does a boomerang work? Well, it relies on three fundamental principles. Lift, relative velocity, and gyroscopic precession. Now a traditional Australian boomerang is basically just two wings stuck together, and both generate lift that keeps the boomerang in the air. But the thing is, as the boomerang is rotating, the top actually rotates with the direction the boomerang is moving, while the bottom is rotating in the opposite direction. So air flows faster over the top of the boomerang, creat...
#
# ================================================================================
#
# Chunk ID: liqF6EamiE4_0
# Video ID: liqF6EamiE4
# Title: can you solve this shadow illusion?
# Description: when sunlight shines through a small hole, it casts a circular image on the wall regardless of the shape of the hole. the size of the ...
# Category: Physics
# Published At: 2011-06-13T22:30:47Z
# Summary: We have that card with a little round hole in it and what I want you to do is hold it up and try to cast a shadow on that wall there. Before you do it, predict what we're gonna see. We will see that figure enlarged on the wall. It'll be a triangle. Why is it going to a circle though? You look at the Sun it looks at around.
# Chunk Content: We have that card with a little round hole in it and what I want you to do is hold it up and try to cast a shadow on that wall there and I want you before you do it to predict what we're gonna see. Shadow of the card. Shadow of the card. With a little hole in it. We will see that figure enlarged on the wall. It's not very pronounced but you can actually do see the little hole in it and of course me. My next question for you is we have this card. What's that like? It's a big a hole. Can you tell ...
#
# ================================================================================
#
# Chunk ID: liqF6EamiE4_1
# Video ID: liqF6EamiE4
# Title: can you solve this shadow illusion?
# Description: when sunlight shines through a small hole, it casts a circular image on the wall regardless of the shape of the hole. the size of the ...
# Category: Physics
# Published At: 2011-06-13T22:30:47Z
# Summary: re seeing is... A projection of the sun. I've never thought about it before. Well, I did photography at school and we did pinhole cameras. The hole actually reflects what it's showing on the wall. So? So you see what you see on the other side.
# Chunk Content: re seeing is... A projection of the sun. I've never thought about it before. I think that you actually know and I think you have actually thought about it before. But I think you're not queuing that right part of your brain that knows the answer. Yeah, probably. There's a part of your brain that knows the answer. Well, I did photography at school and we did pinhole cameras. The hole actually reflects what it's showing on the wall. So? So you see what you see on the other side. So what's that? So...
#
# ================================================================================
#
# Chunk ID: tLMpdBjA2SU_0
# Video ID: tLMpdBjA2SU
# Title: anti-gravity wheel explained
# Description: it's a little shaky but if you average out the oscillations i think the result is clear. again, huge thank you's to a/prof emeritus rod ...
# Category: Physics
# Published At: 2014-03-19T19:53:37Z
# Summary: Standing on the scale, the wheel is spinning and it still weighs 91 kilograms. Let's see what happens when I throw it up over my head. In three, two, one. What do you think? I don't know about you, but to me it looked like a shaky mess.
# Chunk Content: Standing on the scale, the wheel is spinning and it still weighs 91 kilograms. You've made your prediction. Let's see what happens when I throw it up over my head. In three, two, one. What do you think? I don't know about you, but to me it looked like a shaky mess. Let's watch that again in slow-mo and I will graph the scale readings. As you can see, during the lift the scale oscillates around 91 kilograms, the same as it read when I was stationary. So it seems the apparatus doesn't get heavier ...
#
# ================================================================================
#
# Chunk ID: tLMpdBjA2SU_1
# Video ID: tLMpdBjA2SU
# Title: anti-gravity wheel explained
# Description: it's a little shaky but if you average out the oscillations i think the result is clear. again, huge thank you's to a/prof emeritus rod ...
# Category: Physics
# Published At: 2014-03-19T19:53:37Z
# Summary: ovide any torque with my hand to counter that gravitational torque, which makes it feel so awkward when you're trying to hold it when it's static. When you apply a torque, as you were, then there's a force up on one side of the hand and down on the other side. And if you decrease the force on both sides, then it will actually feel lighter.
# Chunk Content: ovide any torque with my hand to counter that gravitational torque, which is what makes it feel so awkward when you're trying to hold it when it's static. When you apply a torque, as you were, then there's a force up on one side of the hand and down on the other side. And if you decrease the force on both sides, then it will actually feel lighter. It feels lighter without actually getting lighter. Yeah, yeah. What it does is to decrease the apparent weight that you're feeling....
#
# ================================================================================
#
# Chunk ID: 5RLQ9WMP2Es_0
# Video ID: 5RLQ9WMP2Es
# Title: ice spikes explained
# Description: why do spikes form on ice cubes? without them the world would be vastly different. awesome jingle by accent: ...
# Category: Physics
# Published At: 2015-05-28T15:00:01Z
# Summary: Ice cubes cool first from their top surface where they're in direct contact with the cold freezer air. As that ice freezes it expands by roughly 8% and that is due to hydrogen bonding between the water molecules. So as the ice grows in from all sides the water in the middle has nowhere to go and it is forced up and out through a hole in the ice.
# Chunk Content: Have you ever made ice cubes and then found that when you take them out of the freezer there are spikes on them? This phenomenon has caused a lot of curiosity and some concern. The truth is there's a simple physical process. responsible for ice cube spikes. Ice cubes cool first from their top surface where they're in direct contact with the cold freezer air and from which evaporative cooling can occur. So the first ice crystals form on the surface of the ice cube and along its edges. Now as that...
#
# ================================================================================
#
# Chunk ID: 5RLQ9WMP2Es_1
# Video ID: 5RLQ9WMP2Es
# Title: ice spikes explained
# Description: why do spikes form on ice cubes? without them the world would be vastly different. awesome jingle by accent: ...
# Category: Physics
# Published At: 2015-05-28T15:00:01Z
# Summary: If there wasn't very much ice on the earth to begin with, it would all sink to the bottom of bodies of water, including arctic sea ice. And that means the Earth's surface would be less reflective, so it would absorb more heat from the sun.
# Chunk Content: ecause if there wasn't very much ice on the earth to begin with, it would all sink to the bottom of bodies of water, including arctic sea ice. ice. And that means the Earth's surface would be less reflective, so it would absorb more heat from the sun and it would get a lot warmer. So if ice didn't float, if ice was denser than water, either the Earth would be much colder than it is now or much hotter than it is now. And in either case, life on Earth might not exist. But if it did, we wouldn't be...
#
# ================================================================================
#
# Chunk ID: vqDbMEdLiCs_0
# Video ID: vqDbMEdLiCs
# Title: misconceptions about temperature
# Description: made for abc tv catalyst http://www.abc.net.au/catalyst/ as an extended version of my comparing temperatures video: ...
# Category: Physics
# Published At: 2012-08-24T11:38:39Z
# Summary: When you touch an object and it feels warm or cold, what is that really telling you about the object? Here I have a metal hard drive and a book. Which one do you think will feel warmer? The book? Or the hard drive the temperatures.
# Chunk Content: When you touch an object and it feels warm or cold, what is that really telling you about the object? Here I have a metal hard drive and a book. And I'm going to ask people to compare their temperatures. Which one do you think will feel warmer? The book? Or the hard drive the temperatures. Yeah, tell me if one is hotter or colder or if they're the same temperature How do they feel this is slightly cooler than this one? Yeah, that's former. Yeah Yeah, agree. I'd say the hard drive is a lot colder...
#
# ================================================================================
#
# Chunk ID: vqDbMEdLiCs_1
# Video ID: vqDbMEdLiCs
# Title: misconceptions about temperature
# Description: made for abc tv catalyst http://www.abc.net.au/catalyst/ as an extended version of my comparing temperatures video: ...
# Category: Physics
# Published At: 2012-08-24T11:38:39Z
# Summary: When you touch something, you don't actually feel temperature. You feel the rate at which heat is conducted either towards or away from you. Think about this next time you hop out of the shower in winter. It's much nicer to stand on the bath mat than on the tile beside it.
# Chunk Content: eat is transferred. from one object to another. So when you felt these blocks originally, I know this one felt a lot colder, but you know from the other example we did that they must both be at the same temperature, because they've both been outside for a while. We see that the aluminium block is melting the ice faster than the plastic block because it's conducting the heat to the ice cube faster. With the plastic block it's a worse thermal conductor so heat is being transferred less quickly to ...
#
# ================================================================================

# %%
import gc
gc.collect()
# Out:
# 176

# %% [markdown]
# ### Final Data Cleaning Followed by Embedding

# %%
def clean_text(text):
    if not text:
        return ""
    # Remove HTML entities
    text = re.sub(r'&[#A-Za-z0-9]+;', ' ', text)
    # Remove any other non-alphanumeric characters except spaces
    text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)
    # Replace multiple spaces with a single space
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def chunks_to_json(chunks, embeddings_model, filename="3-chunked_transcriptions.json", batch_size=20):
    all_embeddings = []

    for i in tqdm(range(0, len(chunks), batch_size), desc="Processing Chunks in Batches"):
        batch = chunks[i:i + batch_size]
        embeddings = []

        for chunk in batch:
            # Clean the transcription, title, and description
            chunk['page_content'] = clean_text(chunk['page_content'])
            chunk['metadata']['title'] = clean_text(chunk['metadata']['title'])
            chunk['metadata']['description'] = clean_text(chunk['metadata']['description'])

            # Compute embeddings for each chunk
            embedding = embeddings_model.embed_query(chunk['page_content'])
            embeddings.append({
                "metadata": chunk['metadata'],
                "embedding": embedding,
                "content": chunk['page_content']
            })

        all_embeddings.extend(embeddings)

    # Save all embeddings and metadata to a JSON file at once
    with open(filename, 'w') as f:
        json.dump(all_embeddings, f, indent=4)

# Initialize embeddings
embeddings_model = OpenAIEmbeddings(api_key=OPENAI_API_KEY, model='text-embedding-ada-002')

# Save chunks to a JSON file
chunks_to_json(chunks, embeddings_model)
# Out:
# Processing Chunks in Batches: 100%|██████████| 58/58 [04:40<00:00,  4.83s/it]

# %%
files.download('/content/3-chunked_transcriptions.json')

# %% [markdown]
# ### Check and remove duplicate chunks_ids (updated videos by the YT channel)

# %%
import gc
gc.collect()

with open('/content/3-chunked_transcriptions.json', 'r') as f:
    chunked_transcriptions = json.load(f)

# %%
len(chunked_transcriptions)
# Out:
# 1141

# %%
# Extract chunk IDs and check for duplicates
chunk_ids = [chunk['metadata']['chunk_id'] for chunk in chunked_transcriptions]
unique_chunk_ids = set(chunk_ids)
duplicate_chunk_ids = [chunk_id for chunk_id in unique_chunk_ids if chunk_ids.count(chunk_id) > 1]

# Number of unique chunk IDs and any duplicates
num_unique_chunk_ids = len(unique_chunk_ids)
num_total_chunk_ids = len(chunk_ids)
num_duplicates = len(duplicate_chunk_ids)

print(f"Total chunk IDs: {num_total_chunk_ids}")
print(f"Unique chunk IDs: {num_unique_chunk_ids}")
print(f"Number of duplicate chunk IDs: {num_duplicates}")
print(f"Duplicate chunk IDs: {duplicate_chunk_ids}")
# Out:
# Total chunk IDs: 1141
# Unique chunk IDs: 1066
# Number of duplicate chunk IDs: 75
# Duplicate chunk IDs: ['AaZ_RSt0KP8_0', 'Q51-gLL_MRM_3', 'Q51-gLL_MRM_0', 'uxPdPpi5W4o_2', 'R13BD8qKeTg_0', 'pir_muTzYM8_0', 'S2xHZPH5Sng_1', 'uxPdPpi5W4o_3', 'C_covjcIcZ4_0', 'R13BD8qKeTg_2', 'R13BD8qKeTg_3', '0dqX3NjwaQs_0', 'S2xHZPH5Sng_5', 'dvk2PQNcg8w_5', 'wQmnztyXwVA_0', '0dqX3NjwaQs_3', '3LopI4YeC4I_0', '3LopI4YeC4I_1', 'AaZ_RSt0KP8_3', 'S2xHZPH5Sng_6', 'S1tFT4smd6E_2', 'S1tFT4smd6E_1', 'Ux33-5k8cjg_0', 'dvk2PQNcg8w_0', 'Q51-gLL_MRM_2', 'AaZ_RSt0KP8_2', 'u3FB2SuKFfI_1', 'R13BD8qKeTg_1', 'dvk2PQNcg8w_4', '3LopI4YeC4I_4', 'sehKAccM8p0_0', 'AaZ_RSt0KP8_1', 'AaZ_RSt0KP8_6', '16Ci_2bN_zc_2', 'AaZ_RSt0KP8_7', '16Ci_2bN_zc_1', 'UMnQWn1rkAA_0', 'AaZ_RSt0KP8_4', 'pir_muTzYM8_1', '3LopI4YeC4I_3', 'Ux33-5k8cjg_1', '16Ci_2bN_zc_6', 'S1tFT4smd6E_3', 'S2xHZPH5Sng_2', 'dvk2PQNcg8w_3', '0dqX3NjwaQs_1', 'wQmnztyXwVA_1', 'AaZ_RSt0KP8_5', 'S2xHZPH5Sng_3', 'S1tFT4smd6E_0', 'CRSDxGtcsxE_0', 'pir_muTzYM8_4', 'uxPdPpi5W4o_0', 'pir_muTzYM8_2', '16Ci_2bN_zc_0', 'Q51-gLL_MRM_4', 'Q51-gLL_MRM_1', '6wr_Zw1uGY8_1', 'pir_muTzYM8_5', 'S2xHZPH5Sng_0', '3LopI4YeC4I_2', '0dqX3NjwaQs_2', 'eUzB0L0mSCI_2', 'dvk2PQNcg8w_1', '6wr_Zw1uGY8_0', 'S2xHZPH5Sng_4', 'u3FB2SuKFfI_0', 'eUzB0L0mSCI_0', 'eUzB0L0mSCI_1', 'pir_muTzYM8_3', '16Ci_2bN_zc_5', 'dvk2PQNcg8w_2', '16Ci_2bN_zc_3', '16Ci_2bN_zc_4', 'uxPdPpi5W4o_1']

# %%
# Cleaning Duplicates
# Create a dictionary to store the latest version of each chunk based on chunk_id
latest_chunks = {}

for chunk in chunked_transcriptions:
    chunk_id = chunk['metadata']['chunk_id']
    published_at = chunk['metadata']['published_at']

    # If the chunk_id is already in the dictionary, compare the published_at dates
    if chunk_id in latest_chunks:
        existing_published_at = latest_chunks[chunk_id]['metadata']['published_at']
        if published_at > existing_published_at:
            latest_chunks[chunk_id] = chunk
    else:
        latest_chunks[chunk_id] = chunk

# Convert the dictionary back to a list and overwrite chunked_transcriptions
chunked_transcriptions = list(latest_chunks.values())

# Number of unique chunk IDs and any duplicates
num_unique_chunk_ids = len(set([chunk['metadata']['chunk_id'] for chunk in chunked_transcriptions]))
num_total_chunk_ids = len(chunked_transcriptions)

print(f"Total chunk IDs: {num_total_chunk_ids}")
print(f"Unique chunk IDs: {num_unique_chunk_ids}")
# Out:
# Total chunk IDs: 1066
# Unique chunk IDs: 1066

# %% [markdown]
# ## Pincone Upsert

# %%
# Initialize Pinecone
pc = Pinecone(api_key=PC_API_KEY)

cloud = os.environ.get('PINECONE_CLOUD') or 'aws'
region = os.environ.get('PINECONE_REGION') or 'us-east-1'
spec = ServerlessSpec(cloud=cloud, region=region)

index_name = "veritasium-vs-final"

# %%
# Check if index already exists (it shouldn't if this is first time)
if index_name not in pc.list_indexes().names():
    # If does not exist, create index
    pc.create_index(
        index_name,
        dimension=1536,  # Dimension for OpenAI embeddings
        metric="cosine",
        spec=spec
    )
    # Wait for index to be initialized
    while not pc.describe_index(index_name).status['ready']:
        time.sleep(1)

# Connect to index
index = pc.Index(index_name)
# View index stats
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %%
# Function to simplify metadata
def simplify_metadata(metadata: Dict[str, Any], transcription: str) -> Dict[str, Any]:
    simplified_metadata = {}
    for key, value in metadata.items():
        if isinstance(value, (str, int, float, bool)):
            simplified_metadata[key] = value
        elif isinstance(value, list) and all(isinstance(item, str) for item in value):
            simplified_metadata[key] = value
        else:
            simplified_metadata[key] = str(value)
    simplified_metadata['transcription'] = transcription  # Add the transcription to the metadata
    return simplified_metadata

# Function to upload transcriptions to Pinecone
def upload_transcriptions(transcriptions: List[Dict[str, Any]], batch_size: int = 64):
    vector_ids = []
    seen_ids = set()  # To check for duplicate IDs

    for i in tqdm(range(0, len(transcriptions), batch_size)):
        i_end = min(i + batch_size, len(transcriptions))
        batch = transcriptions[i:i_end]
        to_upsert = []

        for chunk in batch:
            chunk_id = chunk['metadata']['chunk_id']

            # Check for duplicate IDs in input data
            if chunk_id in seen_ids:
                print(f"Duplicate chunk ID found in input data: {chunk_id}")
                continue

            seen_ids.add(chunk_id)

            # Simplify metadata
            simplified_metadata = simplify_metadata(chunk['metadata'], chunk['content'])
            vector_ids.append(chunk_id)
            to_upsert.append({
                'id': chunk_id,
                'values': chunk['embedding'],
                'metadata': simplified_metadata
            })

        # Upsert/insert these records to Pinecone
        response = index.upsert(vectors=to_upsert)
        # Print metadata to ensure upsert was successful
        print(f"Upserted batch {i} to {i_end}")

    return vector_ids

# Example usage
vector_ids = upload_transcriptions(chunked_transcriptions)

# Wait for the upserts to complete
import time
time.sleep(5)

# Fetch the first vector ID and check metadata
vector_id = vector_ids[0]  # Using the first ID from the upserted vectors
response = index.fetch(ids=[vector_id])

# Print the metadata of the fetched vector
if vector_id in response['vectors']:
    fetched_vector = response['vectors'][vector_id]
    print("Fetched vector metadata:", json.dumps({
        "id": fetched_vector['id'],
        "metadata": fetched_vector['metadata']
    }, indent=2))
else:
    print("Vector not found.")
# Out:
#   6%|▌         | 1/17 [00:01<00:19,  1.23s/it]
# Upserted batch 0 to 64
#  12%|█▏        | 2/17 [00:01<00:14,  1.05it/s]
# Upserted batch 64 to 128
#  18%|█▊        | 3/17 [00:02<00:12,  1.16it/s]
# Upserted batch 128 to 192
#  24%|██▎       | 4/17 [00:03<00:11,  1.11it/s]
# Upserted batch 192 to 256
#  29%|██▉       | 5/17 [00:04<00:09,  1.22it/s]
# Upserted batch 256 to 320
#  35%|███▌      | 6/17 [00:05<00:08,  1.26it/s]
# Upserted batch 320 to 384
#  41%|████      | 7/17 [00:05<00:07,  1.28it/s]
# Upserted batch 384 to 448
#  47%|████▋     | 8/17 [00:06<00:06,  1.36it/s]
# Upserted batch 448 to 512
#  53%|█████▎    | 9/17 [00:07<00:05,  1.42it/s]
# Upserted batch 512 to 576
#  59%|█████▉    | 10/17 [00:07<00:04,  1.44it/s]
# Upserted batch 576 to 640
#  65%|██████▍   | 11/17 [00:08<00:04,  1.46it/s]
# Upserted batch 640 to 704
#  71%|███████   | 12/17 [00:09<00:03,  1.48it/s]
# Upserted batch 704 to 768
#  76%|███████▋  | 13/17 [00:09<00:02,  1.47it/s]
# Upserted batch 768 to 832
#  82%|████████▏ | 14/17 [00:10<00:02,  1.47it/s]
# Upserted batch 832 to 896
#  88%|████████▊ | 15/17 [00:11<00:01,  1.50it/s]
# Upserted batch 896 to 960
#  94%|█████████▍| 16/17 [00:11<00:00,  1.48it/s]
# Upserted batch 960 to 1024
# 100%|██████████| 17/17 [00:12<00:00,  1.38it/s]
# Upserted batch 1024 to 1066
# Fetched vector metadata: {
#   "id": "scliyWrN7mk_0",
#   "metadata": {
#     "category": "Physics",
#     "chunk_id": "scliyWrN7mk_0",
#     "description": "why are bicycles stable the most common answer is gyroscopic effects but this is not right",
#     "published_at": "2024-04-17T16:20:50Z",
#     "summary": "Bikes are stable without riders because they're cleverly designed to steer themselves. If they start falling to one side, the handlebars turn in that direction to steer the wheels back underneath them. Just watch what happens when we lock the handle bars completely, so you can only go straight ahead.",
#     "title": "how bikes actually work",
#     "transcription": "How do bikes without riders stay upright As long as a bike is moving with sufficient speed it can keep coasting indefinitely But it turned out the ground where we went to test this effect was really bumpy But the bike still manages to absorb all these perturbations and remain stable So how does it do this I think most people believe it s the wheels spinning that creates some sort of gyroscopic effect that resists falling over Just like in this demonstration of gyroscopic precession the wheels stays upright even though gravity is pulling it down But this is not why bikes are stable Just watch what happens when we lock the handlebars completely so you can only go straight ahead The real reason bicycles are stable without riders is because they re cleverly designed to steer themselves If they start falling to one side the handlebars turn in that direction to steer the wheels back underneath them",
#     "url": "https://www.youtube.com/watch?v=scliyWrN7mk",
#     "video_id": "scliyWrN7mk"
#   }
# }
